# %% [markdown]
# #
#
# # 作業目標:
#
#     1. 藉由固定的 dataset, 來驗證不同loss function
#     2. Dataset 的特性跟我們選用的loss function 對accrancy 的影響
#
#
# # 作業重點:
#     請分別選用 "MSE", "binary _crossentropy"
#     查看Train/test accurancy and loss rate

# %% [markdown]
# # 導入必要的函數

# %%
from keras.datasets import cifar10
import numpy as np
np.random.seed(10)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 資料準備

# %%
#取得Keras Dataset
(x_img_train,y_label_train),(x_img_test,y_label_test)=cifar10.load_data()

# %%
#確認 CIFAR10 Dataset 資料維度
print("train data:",'images:',x_img_train.shape,
      " labels:",y_label_train.shape) 
print("test  data:",'images:',x_img_test.shape ,
      " labels:",y_label_test.shape)
# Out:
# train data: images: (50000, 32, 32, 3)  labels: (50000, 1)
# test  data: images: (10000, 32, 32, 3)  labels: (10000, 1)

# %%
#資料正規化
x_img_train_normalize = x_img_train.astype('float32') / 255.0
x_img_test_normalize = x_img_test.astype('float32') / 255.0

# %%
#針對Label 做 ONE HOT ENCODE
from keras.utils import np_utils
y_label_train_OneHot = np_utils.to_categorical(y_label_train)
y_label_test_OneHot = np_utils.to_categorical(y_label_test)
y_label_test_OneHot.shape
# Out:
# (10000, 10)

# %% [markdown]
# # 建立模型

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

# %%
model = Sequential()

# %%
#卷積層1

# %%
model.add(Conv2D(filters=32,kernel_size=(3,3),
                 input_shape=(32, 32,3), 
                 activation='relu', 
                 padding='same'))

# %%
model.add(Dropout(rate=0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#卷積層2與池化層2

# %%
model.add(Conv2D(filters=64, kernel_size=(3, 3), 
                 activation='relu', padding='same'))

# %%
model.add(Dropout(0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#建立神經網路(平坦層、隱藏層、輸出層)

# %%
model.add(Flatten())
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(1024, activation='relu'))
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(10, activation='softmax'))

# %%
#檢查model 的STACK
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              4195328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 4,224,970
# Trainable params: 4,224,970
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 載入之前訓練的模型

# %%
try:
    model.load_weights("SaveModel/cifarCnnModel.h5")
    print("載入模型成功!繼續訓練模型")
except :    
    print("載入模型失敗!開始訓練一個新模型")
# Out:
# 載入模型失敗!開始訓練一個新模型

# %% [markdown]
# # 訓練模型

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#定義一個繪圖函數
def show_train_history(train_history,train_acc,test_acc):
    plt.plot(train_history.history[train_acc])
    plt.plot(train_history.history[test_acc])
    plt.title('Train History')
    plt.ylabel(train_acc)
    plt.xlabel('Epoch')
    plt.legend(['train_acc', 'val_acc'], loc='upper left')
    plt.show()

# %%
'''
作業:
請分別選用 "MSE", "binary _crossentropy"
查看Train/test accurancy and loss rate
'''

model.compile(loss='MSE', optimizer='sgd', metrics=['accuracy'])
#模型訓練, "Train_History" 把訓練過程所得到的數值存起來
train_history1 = model.fit(x_img_train_normalize, y_label_train_OneHot,
                        validation_split=0.25,
                        epochs=12, batch_size=128, verbose=1)         

#validation_split：在0和1之間浮動。用作驗證數據的訓練數據的分數。
#該模型將訓練數據的這一部分分開，不會對其進行訓練，並將在每個時期結束時評估該數據的損失和任何模型指標。
#[batch_size]：整數或None。每個梯度更新的樣本數。指定，batch_size為128
# Out:
# Train on 37500 samples, validate on 12500 samples
# Epoch 1/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0906 - accuracy: 0.0998 - val_loss: 0.0899 - val_accuracy: 0.1143
# Epoch 2/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0902 - accuracy: 0.1074 - val_loss: 0.0898 - val_accuracy: 0.1289
# Epoch 3/12
# 37500/37500 [==============================] - 100s 3ms/step - loss: 0.0900 - accuracy: 0.1155 - val_loss: 0.0898 - val_accuracy: 0.1382
# Epoch 4/12
# 37500/37500 [==============================] - 99s 3ms/step - loss: 0.0899 - accuracy: 0.1173 - val_loss: 0.0897 - val_accuracy: 0.1474
# Epoch 5/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0898 - accuracy: 0.1236 - val_loss: 0.0896 - val_accuracy: 0.1532
# Epoch 6/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0897 - accuracy: 0.1287 - val_loss: 0.0895 - val_accuracy: 0.1586
# Epoch 7/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0895 - accuracy: 0.1341 - val_loss: 0.0894 - val_accuracy: 0.1662
# Epoch 8/12
# 37500/37500 [==============================] - 102s 3ms/step - loss: 0.0894 - accuracy: 0.1391 - val_loss: 0.0894 - val_accuracy: 0.1746
# Epoch 9/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0893 - accuracy: 0.1439 - val_loss: 0.0893 - val_accuracy: 0.1780
# Epoch 10/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0892 - accuracy: 0.1501 - val_loss: 0.0892 - val_accuracy: 0.1827
# Epoch 11/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0891 - accuracy: 0.1539 - val_loss: 0.0891 - val_accuracy: 0.1906
# Epoch 12/12
# 37500/37500 [==============================] - 98s 3ms/step - loss: 0.0889 - accuracy: 0.1558 - val_loss: 0.0890 - val_accuracy: 0.1951

# %%
show_train_history(train_history1,'accuracy','val_accuracy')

# %%
show_train_history(train_history1,'loss','val_loss')

# %%
scores = model.evaluate(x_img_test_normalize, y_label_test_OneHot)
print()
print('accuracy=',scores[1])
# Out:
# 10000/10000 [==============================] - 6s 616us/step
#
# accuracy= 0.1941000074148178

# %%
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
train_history2 = model.fit(x_img_train_normalize, y_label_train_OneHot,
                        validation_split=0.25,
                        epochs=12, batch_size=128, verbose=1)
# Out:
# Train on 37500 samples, validate on 12500 samples
# Epoch 1/12
# 37500/37500 [==============================] - 103s 3ms/step - loss: 0.3172 - accuracy: 0.9000 - val_loss: 0.3169 - val_accuracy: 0.9000
# Epoch 2/12
# 37500/37500 [==============================] - 102s 3ms/step - loss: 0.3128 - accuracy: 0.9000 - val_loss: 0.3130 - val_accuracy: 0.9000
# Epoch 3/12
# 37500/37500 [==============================] - 106s 3ms/step - loss: 0.3071 - accuracy: 0.9000 - val_loss: 0.3082 - val_accuracy: 0.9000
# Epoch 4/12
# 37500/37500 [==============================] - 104s 3ms/step - loss: 0.3014 - accuracy: 0.9001 - val_loss: 0.3040 - val_accuracy: 0.9000
# Epoch 5/12
# 37500/37500 [==============================] - 103s 3ms/step - loss: 0.2972 - accuracy: 0.9001 - val_loss: 0.2998 - val_accuracy: 0.9000
# Epoch 6/12
# 37500/37500 [==============================] - 108s 3ms/step - loss: 0.2935 - accuracy: 0.9003 - val_loss: 0.2970 - val_accuracy: 0.9000
# Epoch 7/12
# 37500/37500 [==============================] - 104s 3ms/step - loss: 0.2906 - accuracy: 0.9005 - val_loss: 0.2941 - val_accuracy: 0.9000
# Epoch 8/12
# 37500/37500 [==============================] - 103s 3ms/step - loss: 0.2883 - accuracy: 0.9007 - val_loss: 0.2926 - val_accuracy: 0.9000
# Epoch 9/12
# 37500/37500 [==============================] - 103s 3ms/step - loss: 0.2864 - accuracy: 0.9008 - val_loss: 0.2906 - val_accuracy: 0.9001
# Epoch 10/12
# 37500/37500 [==============================] - 103s 3ms/step - loss: 0.2847 - accuracy: 0.9008 - val_loss: 0.2894 - val_accuracy: 0.9000
# Epoch 11/12
# 37500/37500 [==============================] - 104s 3ms/step - loss: 0.2827 - accuracy: 0.9011 - val_loss: 0.2874 - val_accuracy: 0.9001
# Epoch 12/12
# 37500/37500 [==============================] - 104s 3ms/step - loss: 0.2808 - accuracy: 0.9011 - val_loss: 0.2857 - val_accuracy: 0.9001

# %%
show_train_history(train_history2,'accuracy','val_accuracy')

# %%
show_train_history(train_history2,'loss','val_loss')

# %%
scores = model.evaluate(x_img_test_normalize, y_label_test_OneHot)
print()
print('accuracy=',scores[1])
# Out:
# 10000/10000 [==============================] - 6s 649us/step
#
# accuracy= 0.900087296962738
