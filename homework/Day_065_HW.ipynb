# %% [markdown]
# # 作業
# * 選擇分類資料集(右下)-螺旋雙臂 - 交錯六群，限定特徵只能使用前兩個，隱藏層 2 層滿 (共 8 * 2 =16 個神經元)，
#   遞迴次數只允許跑到500次，但可以自由調整 批次大小、學習速率、啟動函數、正規化選項與參數
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的上述幾項參數與 Test Loss 數

# %%
import pandas as pd
print('Classification-Spiral:')
Header=['Batch size','Learning rate','Activation','Regularization','Regularization rate','Test loss','']
df=pd.DataFrame([[10,0.3,'Relu','None',0,'Failed',''],
                 [10,0.3,'Tanh','None',0,'Failed',''],
                 [10,0.3,'Sigmoid','None',0,0.443,'*'],
                 [10,0.3,'Linear','None',0,0.503,''],
                 [10,0.3,'Sigmoid','L1',0.01,0.497,''],
                 [10,0.3,'Sigmoid','L2',0.01,0.496,''],
                 [7,0.3,'Sigmoid','None',0,0.407,'**']
                ],columns=Header)
df
# Out:
# Classification-Spiral:
#    Batch size  Learning rate Activation Regularization  Regularization rate  \
# 0          10            0.3       Relu           None                 0.00
# 1          10            0.3       Tanh           None                 0.00
# 2          10            0.3    Sigmoid           None                 0.00
# 3          10            0.3     Linear           None                 0.00
# 4          10            0.3    Sigmoid             L1                 0.01
# 5          10            0.3    Sigmoid             L2                 0.01
# 6           7            0.3    Sigmoid           None                 0.00
#
#   Test loss
# 0    Failed
# 1    Failed
# 2     0.443   *
# 3     0.503
# 4     0.497
# 5     0.496
# 6     0.407  **

# %% [markdown]
# 測試誤差 (Test Loss) 最低能到多少? 請回答你的上述幾項參數與 Test Loss 數
# >測試誤差 (Test Loss) 最低到0.407, Batch size=7, Learning rate=0.3, Activation=Sigmoid, Regularization=None.
