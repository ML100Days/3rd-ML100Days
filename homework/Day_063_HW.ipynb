# %% [markdown]
# # 作業
# * 在精簡深度學習的方式上 : 卷積類神經 (CNN) 採用像素遠近，而遞歸類神經 (RNN) 採用著則是時間遠近
# * 那麼，既然有著類似的設計精神，兩者是否有可能互換應用呢?

# %% [markdown]
# >- CNN是空間擴展，神經元與特征卷積；RNN是時間擴展，神經元與多個時間輸出計算.
# >- RNN可以用於描述時間上連續狀態的輸出，有記憶功能；CNN用於靜態輸出.
# >- 以目前初學的知識, 兩者是否有可能互換應用? 答案未知. 但已知可以組合運用.
